# %%
from pyspark import SparkConf,SparkContext

# %%
conf=SparkConf().setAppName("Read File")

# %%
#entry point of spark programm
sc=SparkContext.getOrCreate(conf=conf)

# %%
# transformation
text_file=sc.textFile("FileStore/tables/Sample-2.txt")

# %%
#this is action
text_file.collect()
# Out:
# Out[22]: ['1 2 3 4 5', '3 4 5 66 77', '12 43 6 7 8', '12 12 33']
